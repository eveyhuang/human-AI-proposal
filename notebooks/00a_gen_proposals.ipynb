# %% [markdown]
# # 1 Gen Proposals
#
# This notebook runs the redesigned proposal-generation stage for the study.
#
# It does exactly two things:
# 1. Pass A: generate AI ideas for each requested condition.
# 2. Pass B: after all ideas are saved, expand those ideas into full proposals with the same model.
#
# It does not run rephrasing, embedding preparation, or analyses.

# %%
CONDITIONS_TO_RUN = [ 'one_at_a_time', 'persona']
MODELS_TO_USE = ['gpt-5.5', 'gemini-3.1-pro-preview', 'claude-sonnet-5']

GENERATION_TEMPERATURE = 0.9
MAX_TOKENS_IDEAS = 8000
MAX_TOKENS_PROPOSALS = 16000
RETRY_DELAYS = [2, 5, 10]
SAVE_PROGRESS_EVERY_N_CALLS = 3
RESUME_OK = True

RUN_TEST_CALLS = False
TEST_MODEL = MODELS_TO_USE[0]
TEST_MAX_TOKENS = MAX_TOKENS_IDEAS

# Set to a fixed string only if you want to pin new outputs to a custom run id.
RUN_ID = None

# %%
import sys
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd().resolve()
if not (PROJECT_ROOT / 'src').exists():
    PROJECT_ROOT = PROJECT_ROOT.parent.resolve()
if str(PROJECT_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT / 'src'))

from ai_models_interface import AIModelsInterface
from prompt_templates import PromptManager
from proposal_generation import (
    build_condition_registry,
    build_idea_prompt_kwargs,
    find_project_root,
    idea_schedule_rows,
    load_human_target_roster,
    load_persona_cards,
    load_shared_call_context,
    load_target_proposal_count,
    now_run_id,
    parse_generated_ideas_response,
    run_idea_generation_for_condition,
    run_proposal_expansion_for_condition,
)

PROJECT_ROOT = find_project_root(PROJECT_ROOT)
shared_call_context = load_shared_call_context(PROJECT_ROOT)
human_target_roster = load_human_target_roster(PROJECT_ROOT)
target_n = load_target_proposal_count(PROJECT_ROOT)
if target_n != 23:
    raise RuntimeError(f'Expected 23 human comparison proposals, found {target_n}.')

persona_roster = load_persona_cards(PROJECT_ROOT, human_target_roster)
if 'persona' in CONDITIONS_TO_RUN and len(persona_roster) != target_n:
    raise RuntimeError(
        f'Persona roster must contain exactly {target_n} cards, found {len(persona_roster)}.'
    )

prompt_manager = PromptManager()
ai_interface = AIModelsInterface(config_path=str(PROJECT_ROOT / '.env'), override_env=True)
available_models = ai_interface.get_available_models()
resolved_models = [ai_interface.resolve_model_name(model_name) for model_name in MODELS_TO_USE]

missing_models = [model_name for model_name in resolved_models if model_name not in available_models]
if missing_models:
    raise RuntimeError(f'Requested model(s) unavailable with current API keys: {missing_models}')

condition_registry = build_condition_registry(target_n)
stage_run_id = RUN_ID or now_run_id()

print(f'Project root: {PROJECT_ROOT}')
print(f'Human target proposals: {target_n}')
print(f'Available canonical models: {available_models}')
print(f'Conditions to run: {CONDITIONS_TO_RUN}')
# Out:
# INFO:ai_models_interface:OpenAI GPT-5.5 initialized
# INFO:ai_models_interface:Google Gemini initialized
# INFO:ai_models_interface:Anthropic Claude initialized
# Project root: /Users/eveyhuang/Documents/NICO/human-AI-proposal
# Human target proposals: 23
# Available canonical models: ['claude-sonnet-5', 'gemini-3.1-pro-preview', 'gpt-5.5']
# Conditions to run: ['one_at_a_time', 'persona']

# %% [markdown]
# ## Optional Test Calls
#
# Set `RUN_TEST_CALLS = True` to make one sample idea-generation call per condition before the full generation passes. This lets you inspect the exact prompt, raw model output, and parsed JSON without launching all draws.

# %%
test_call_outputs = {}

if not RUN_TEST_CALLS:
    print('RUN_TEST_CALLS is False; skipping sample proposal-generation calls.')
else:
    test_model = ai_interface.resolve_model_name(TEST_MODEL)
    if test_model not in resolved_models:
        raise RuntimeError(f'TEST_MODEL must be one of MODELS_TO_USE after alias resolution: {resolved_models}')

    for condition in CONDITIONS_TO_RUN:
        condition_config = condition_registry[condition]
        schedule = idea_schedule_rows(
            condition_config=condition_config,
            model_name=test_model,
            target_n=target_n,
            persona_roster=persona_roster if condition == 'persona' else None,
        )
        sample_row = schedule[0]
        prompt_kwargs = build_idea_prompt_kwargs(
            shared_call_context=shared_call_context,
            condition_config=condition_config,
            target_n=target_n,
            schedule_row=sample_row,
        )
        prompt = prompt_manager.format_prompt(condition_config['idea_prompt_template'], prompt_kwargs)
        result = ai_interface.generate_content_with_metadata(
            prompt,
            model_name=test_model,
            temperature=GENERATION_TEMPERATURE,
            max_tokens=TEST_MAX_TOKENS,
            retry_delays=RETRY_DELAYS,
        )
        parsed_ideas, parse_error = parse_generated_ideas_response(
            result['raw_response'],
            expected_count=int(sample_row['expected_idea_count']),
            mode=condition_config['idea_generation_mode'],
        ) if not result['error'] else ([], None)

        test_call_outputs[condition] = {
            'condition': condition,
            'model': test_model,
            'prompt_template': condition_config['idea_prompt_template'],
            'idea_generation_mode': condition_config['idea_generation_mode'],
            'sample_call_id': sample_row['idea_call_id'],
            'expected_idea_count': int(sample_row['expected_idea_count']),
            'prompt': prompt,
            'raw_response': result['raw_response'],
            'provider_model_id': result.get('provider_model_id', ''),
            'timestamp': result.get('timestamp', ''),
            'error': result.get('error', ''),
            'parse_error': parse_error,
            'parsed_ideas': parsed_ideas,
        }

    test_call_summary = pd.DataFrame([
        {
            'condition': payload['condition'],
            'model': payload['model'],
            'prompt_template': payload['prompt_template'],
            'expected_idea_count': payload['expected_idea_count'],
            'parsed_idea_count': len(payload['parsed_ideas']),
            'error': payload['error'],
            'parse_error': payload['parse_error'],
        }
        for payload in test_call_outputs.values()
    ])
    display(test_call_summary)

    for condition, payload in test_call_outputs.items():
        print(f'\n=== Test Call: {condition} ===')
        print('Prompt:')
        print(payload['prompt'])
        print('\nRaw response:')
        print(payload['raw_response'])
        print('\nParsed ideas:')
        display(pd.DataFrame(payload['parsed_ideas']))
# Out:
# RUN_TEST_CALLS is False; skipping sample proposal-generation calls.

# %% [markdown]
# ## Generate ideas

# %%
# Pass A: generate and save all ideas before any proposal expansion begins.
idea_stage_outputs = {}

for condition in CONDITIONS_TO_RUN:
    print(f'\n=== Pass A: {condition} ===')
    condition_result = run_idea_generation_for_condition(
        project_root=PROJECT_ROOT,
        ai_interface=ai_interface,
        prompt_manager=prompt_manager,
        shared_call_context=shared_call_context,
        condition_config=condition_registry[condition],
        models_to_use=resolved_models,
        target_n=target_n,
        persona_roster=persona_roster if condition == 'persona' else None,
        generation_temperature=GENERATION_TEMPERATURE,
        max_tokens=MAX_TOKENS_IDEAS,
        retry_delays=RETRY_DELAYS,
        save_progress_every_n_calls=SAVE_PROGRESS_EVERY_N_CALLS,
        resume_ok=RESUME_OK,
        run_id=stage_run_id,
    )
    idea_stage_outputs[condition] = condition_result
    print(f"Ideas file: {condition_result['ideas_path']}")
    print(f"Rows: {len(condition_result['ideas_df'])}")
    if condition_result['qa_issues']:
        print('QA issues:')
        for issue in condition_result['qa_issues']:
            print(f'  - {issue}')

idea_qa_summary = []
for condition, result in idea_stage_outputs.items():
    idea_df = result['ideas_df']
    duplicate_titles = int(idea_df['title'].fillna('').duplicated().sum()) if not idea_df.empty else 0
    idea_qa_summary.append(
        {
            'condition': condition,
            'rows': len(idea_df),
            'models': ', '.join(sorted(idea_df['model'].dropna().unique())) if not idea_df.empty else '',
            'duplicate_titles': duplicate_titles,
            'qa_issue_count': len(result['qa_issues']),
            'reused_existing': result['reused_existing'],
        }
    )

pd.DataFrame(idea_qa_summary)
# Out:
# === Pass A: one_at_a_time ===
# Ideas file: /Users/eveyhuang/Documents/NICO/human-AI-proposal/data/ai-proposals/one_at_a_time/ai_ideas_one_at_a_time_20260709_095141.csv
# Rows: 69
#
# === Pass A: persona ===
# Ideas file: /Users/eveyhuang/Documents/NICO/human-AI-proposal/data/ai-proposals/persona/ai_ideas_persona_20260709_095141.csv
# Rows: 69
#        condition  rows                                            models  \
# 0  one_at_a_time    69  claude-sonnet-5, gemini-3.1-pro-preview, gpt-5.5
# 1        persona    69  claude-sonnet-5, gemini-3.1-pro-preview, gpt-5.5
#
#    duplicate_titles  qa_issue_count  reused_existing
# 0                 1               0             True
# 1                 0               0             True

# %%
# Pass B: expand ideas into full proposals only after Pass A completes for all requested conditions.
proposal_stage_outputs = {}

for condition in CONDITIONS_TO_RUN:
    print(f'\n=== Pass B: {condition} ===')
    proposal_result = run_proposal_expansion_for_condition(
        project_root=PROJECT_ROOT,
        ai_interface=ai_interface,
        prompt_manager=prompt_manager,
        shared_call_context=shared_call_context,
        condition_config=condition_registry[condition],
        ideas_df=idea_stage_outputs[condition]['ideas_df'],
        generation_temperature=GENERATION_TEMPERATURE,
        max_tokens=MAX_TOKENS_PROPOSALS,
        retry_delays=RETRY_DELAYS,
        save_progress_every_n_calls=SAVE_PROGRESS_EVERY_N_CALLS,
        resume_ok=RESUME_OK,
        run_id=idea_stage_outputs[condition]['run_id'],
    )
    proposal_stage_outputs[condition] = proposal_result
    print(f"Progress file: {proposal_result['progress_path']}")
    print(f"Complete file: {proposal_result['complete_path']}")
    print(f"Rows: {len(proposal_result['proposals_df'])}")
    if proposal_result['qa_issues']:
        print('Proposal QA issues:')
        for issue in proposal_result['qa_issues'][:10]:
            print(f'  - {issue}')
# Out:
# === Pass B: one_at_a_time ===
# /Users/eveyhuang/Documents/NICO/human-AI-proposal/src/proposal_generation.py:795: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Biomolecular condensates occupy a privileged position in the study of mesoscale emergence: they arise from nanometer-scale interactions among IDRs, folded multivalent domains, and nucleic acids, yet manifest as micron-scale organelles with tunable material properties—liquid, gel, or solid—that dictate cellular physiology and pathology. Condensates underlie ribosome biogenesis, stress response, chromatin organization, and signal transduction, and their aberrant hardening is mechanistically implicated in neurodegenerative diseases (ALS, FTD, Alzheimer's) and cancers. Despite a decade of intense research, the field lacks a predictive, proteome-scale understanding of how primary sequence features translate into emergent material states and higher-order multiphase architectures (e.g., core-shell nucleoli, stress granules with distinct sub-compartments). This gap persists not for want of data, but because relevant information is fragmented across disconnected ecosystems: condensate-composition catalogs (PhaSepDB, DrLLPS, CD-CODE) rarely cross-reference biophysical propensity predictors (PScore, catGRANULE, FuzDrop); interactome resources (BioGRID, STRING, hu.MAP) are seldom integrated with imaging-derived localization atlases (Human Protein Atlas, OpenCell); structural data from cryo-EM/ET remain siloed from single-molecule/FRAP-derived material-property measurements buried in supplementary literature; and disease-mutation repositories (ClinVar, COSMIC) are almost never systematically mapped onto condensate-forming protein grammar. Each dataset alone offers a partial view; only their synthesis can reveal the sequence-to-mesoscale 'grammar' governing condensate emergence. This is precisely the class of problem NCEMS was created to address: a mesoscale phenomenon, abundant public data, and a scientific question unanswerable without cross-disciplinary, cross-dataset integration. The significance is threefold. First, scientifically, resolving the sequence-to-material-state mapping would solve a long-standing puzzle—why do compositionally similar IDRs produce condensates with vastly different viscosities, aging kinetics, and multiphase architectures? Second, medically, a validated grammar-to-phenotype framework would clarify why specific disease mutations trigger pathological liquid-to-solid transitions, informing biomarker discovery and therapeutic targeting of aberrant condensates. Third, methodologically, this project pioneers a generalizable template for mesoscale data synthesis—harmonizing structural, biophysical, network, and clinical data types—that can be extended to other emergent cellular phenomena (e.g., membrane-contact sites, chromatin domains). By convening biophysicists, structural biologists, computational scientists, cell biologists, and clinical geneticists around a common, richly annotated proteome-scale resource, this Working Group will transform condensate biology from a collection of case studies into a predictive, systems-level science, directly advancing NCEMS's mission to understand emergent mesoscale properties and their cellular consequences.' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   proposals_df.at[idx, col] = progress_lookup.at[uid, col]
# /Users/eveyhuang/Documents/NICO/human-AI-proposal/src/proposal_generation.py:795: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'This Working Group is organized around four interconnected research questions that collectively probe how sequence-encoded molecular interactions give rise to emergent mesoscale condensate properties. RQ1: Can a unified, proteome-scale dataset integrating composition, biophysical propensity, interactome, structural, and phenotypic data reveal quantitative relationships between sequence features and condensate material states that are invisible within any single data source? We hypothesize that cross-dataset integration will expose combinatorial 'grammar' signatures (e.g., specific patterns of aromatic residue spacing, charge blockiness, and multivalent domain arrangement) that individually weak predictors fail to capture, but which jointly predict material state with substantially higher accuracy than single-feature models. RQ2: What sequence and interaction-network features distinguish proteins that form single-phase liquid condensates from those forming multiphase, core-shell, or gel/solid architectures? We hypothesize that multiphase organization is predictable from a combination of relative interaction valency, hierarchical binding affinities inferred from interactome connectivity, and differential IDR stickiness, such that proteins with markedly asymmetric interaction strengths preferentially localize to condensate cores versus shells. RQ3: Do disease-associated mutations in condensate-forming proteins preferentially map onto grammar elements predicted to govern material-state transitions, and do these mutations disproportionately drive liquid-to-solid or gel transitions associated with neurodegeneration and cancer? We hypothesize that pathogenic mutations are enriched in sequence regions contributing to metastable liquid-state maintenance (e.g., regions that suppress excessive self-interaction or aggregation-prone motifs), such that mutation-induced grammar disruption is a statistically significant predictor of pathological hardening, independent of mutation location within folded domains. RQ4: Is the sequence-to-mesoscale grammar evolutionarily conserved, and does conservation pattern predict functional importance of specific material states? We hypothesize that grammar elements controlling condensate formation per se (e.g., minimal multivalency thresholds) are broadly conserved across species, whereas fine-tuning elements governing precise material properties (viscosity, aging rate) show lineage-specific variation correlated with organism-specific physiological demands. These hypotheses are testable only through integrative synthesis: RQ1 and RQ2 require simultaneous access to biophysical predictors, interactome data, and imaging-derived localization patterns; RQ3 requires overlaying clinical mutation databases onto a validated grammar model; and RQ4 requires cross-species comparative genomic data layered onto the same framework. No existing single dataset or individual laboratory's data can address these questions, underscoring the necessity of a multi-institutional, multi-database synthesis approach. Successful validation of these hypotheses would establish the first quantitative, generalizable, and mechanistically interpretable framework linking primary sequence information to emergent, function-defining mesoscale organization—directly addressing NCEMS's core scientific vision of understanding how molecular-scale interactions produce unexpected higher-order cellular properties.' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   proposals_df.at[idx, col] = progress_lookup.at[uid, col]
# /Users/eveyhuang/Documents/NICO/human-AI-proposal/src/proposal_generation.py:795: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'The Working Group will execute a four-phase synthesis pipeline over 24 months. Phase 1 (Months 1–6): Data Harmonization. We will systematically extract and standardize data from all eight source ecosystems using programmatic APIs and custom parsers, mapping every entry to a common UniProt-based protein identifier scheme. Composition databases (PhaSepDB, DrLLPS, CD-CODE) will be cross-referenced to resolve naming discrepancies and redundant entries; biophysical predictor outputs (PScore, catGRANULE, FuzDrop) will be recomputed on a standardized proteome build to ensure comparability; interactome data (BioGRID, STRING, hu.MAP) will be filtered by confidence thresholds and integrated into a unified network graph; imaging data (Human Protein Atlas, OpenCell) will be converted into categorical and continuous localization/dynamics features via existing annotation pipelines; cryo-EM/ET structural metadata (EMDB) will be linked to condensate-associated depositions; literature-curated FRAP/single-molecule material-property measurements will undergo manual curation with double-annotation for quality control (target: >500 proteins with quantitative recovery/mobility parameters); ClinVar/COSMIC mutations will be mapped onto condensate-protein sequences with pathogenicity annotations; and UniProt/Pfam conservation scores will be computed across a curated set of representative eukaryotic species. Phase 2 (Months 5–12): CoMA Construction and Grammar Discovery. Harmonized data will populate the Condensate Mesoscale Atlas, a relational database with an accompanying Python/R analysis toolkit. We will apply interpretable machine learning (gradient-boosted trees with SHAP-based feature attribution, and graph neural networks incorporating interactome topology) to predict material-state labels (liquid/gel/solid, single-phase/multiphase) from sequence-derived and network-derived features. Network-based community detection (e.g., Louvain, spectral clustering) applied to interactome subgraphs of condensate proteins will identify architectural modules corresponding to core versus shell components. Phase 3 (Months 10–18): Disease and Evolutionary Analysis. Using the trained grammar model, we will test enrichment of disease mutations within high-importance grammar features via permutation-based statistical testing, stratified by disease category (neurodegenerative vs. oncological). Evolutionary conservation of grammar features will be assessed via phylogenetic comparative methods correlating conservation scores with feature importance rankings. Phase 4 (Months 16–24): Validation and Dissemination. Model predictions will be validated against held-out data not used in training, including recently published condensate proteomic datasets and independent FRAP measurements identified via targeted literature review. All code, harmonized datasets, and trained models will be packaged for public release. The Working Group will meet biweekly via video conference, with two in-person/hybrid intensive workshops (Months 6 and 18) hosted with NCEMS computational and coordination support to resolve integration challenges and co-develop analytical strategies.' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   proposals_df.at[idx, col] = progress_lookup.at[uid, col]
# /Users/eveyhuang/Documents/NICO/human-AI-proposal/src/proposal_generation.py:795: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'This synthesis project will deliver: (1) the Condensate Mesoscale Atlas (CoMA), a publicly released, harmonized dataset unifying sequence, biophysical, structural, network, and clinical data for >2,000 human condensate-associated proteins; (2) an interpretable, validated machine learning framework predicting condensate material state and multiphase architecture from sequence and interactome features, with quantified accuracy against independent test data; (3) a statistically grounded catalog of disease mutations mapped onto predicted grammar-disruption events, generating testable hypotheses for follow-up experimental studies in neurodegeneration and cancer biology; and (4) a cross-species conservation analysis distinguishing universal versus lineage-specific grammar elements. Scientifically, this resolves a fundamental open question regarding how simple sequence-level interactions generate complex, function-defining mesoscale organization—directly advancing NCEMS's mesoscale emergence mission. Practically, CoMA will serve as a community resource enabling rapid, testable predictions for uncharacterized proteins, informing experimental prioritization across dozens of laboratories studying condensate biology, RNA granules, and proteinopathies. Clinically, mutation-grammar disruption maps may identify previously unrecognized pathogenic variants and nominate candidate biomarkers or therapeutic targets for condensate-associated diseases. Methodologically, the integration pipeline developed here—reconciling structural, biophysical, network, imaging, and clinical data types—provides a generalizable template applicable to other emergent mesoscale systems (e.g., membrane contact sites, chromatin loop domains), amplifying NCEMS's broader synthesis mission beyond this specific project. The interdisciplinary Working Group structure will also produce a cohort of trainees fluent in multi-omic integration and interpretable machine learning, seeding the data-savvy scientific workforce NCEMS aims to cultivate, while the open, versioned release of all datasets and models ensures durable, long-term community benefit well beyond the funding period.' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   proposals_df.at[idx, col] = progress_lookup.at[uid, col]
# /Users/eveyhuang/Documents/NICO/human-AI-proposal/src/proposal_generation.py:795: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'This Working Group commits fully to NCEMS's open, team, and reproducible science standards. All code for data extraction, harmonization, and analysis will be developed collaboratively in version-controlled GitHub repositories using continuous integration testing to ensure reproducibility across computing environments. Harmonized datasets, including the full Condensate Mesoscale Atlas, will be deposited in Zenodo with permanent DOIs, versioned at each major analytical milestone, and formatted according to FAIR (Findable, Accessible, Interoperable, Reusable) principles, including standardized metadata schemas compatible with existing condensate databases (PhaSepDB, CD-CODE) to facilitate downstream community adoption. Trained machine learning models will be shared with accompanying model cards documenting training data provenance, performance metrics, known limitations, and intended use cases, mitigating misuse or overinterpretation. Analysis workflows will be containerized (Docker/Singularity) to guarantee computational reproducibility independent of local software environments, and all statistical analyses will follow pre-registered analysis plans deposited on OSF prior to hypothesis testing in Phases 3–4, minimizing analytical flexibility bias. An interactive web-based visualization tool (built on open-source frameworks such as Dash or Shiny) will allow non-computational biologists to query CoMA predictions for individual proteins, lowering barriers to community engagement. All manuscripts arising from this work will be posted as preprints prior to journal submission, and we will pursue publication in venues supporting open peer review. Authorship and credit will follow a contributor-role (CRediT) taxonomy agreed upon at project inception to ensure equitable recognition across the interdisciplinary team, including trainees. Data governance protocols will explicitly address licensing constraints of constituent source databases, ensuring redistributed harmonized data complies with original data-use agreements. Regular open lab meetings, recorded and archived when appropriate, will document decision-making processes, and a public project website will track milestones, releases, and opportunities for external community contributions or critique throughout the project lifecycle.' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   proposals_df.at[idx, col] = progress_lookup.at[uid, col]
# /Users/eveyhuang/Documents/NICO/human-AI-proposal/src/proposal_generation.py:795: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'This proposal requests NCEMS support for a 24-month Working Group comprising six co-investigators (biophysics, structural biology, computational biology, cell biology, and clinical genetics) and four trainees (two graduate students, two postdoctoral researchers) distributed across four institutions to ensure diverse geographic and career-stage representation. Personnel costs constitute the primary budget component: two postdoctoral researchers (1.0 FTE each) will lead data harmonization and machine learning development; two graduate students (0.5 FTE each) will contribute to literature curation of material-property data and disease-mutation mapping under co-investigator supervision. Modest salary support (5–10% effort) is requested for each of the six co-investigators to enable sustained engagement in biweekly meetings, analytical decision-making, and manuscript preparation. Computational resources include cloud computing credits (AWS/Google Cloud) for large-scale interactome graph analyses and machine learning model training, estimated at moderate annual cost, plus data storage for harmonized multi-terabyte imaging and structural datasets. Travel funds are requested for two in-person/hybrid Working Group workshops (Months 6 and 18) to facilitate intensive cross-disciplinary integration sessions, hands-on trainee workshops on machine learning interpretability methods, and in-person resolution of complex data harmonization challenges. Publication costs cover open-access fees for at least three anticipated manuscripts and preprint server deposition. We request NCEMS coordination support for shared computational infrastructure (database hosting, GitHub/Zenodo organizational accounts) and facilitation of interdisciplinary onboarding, including access to NCEMS-provided data science training modules for trainees. No funds are requested for new experimental data generation, consistent with the community-scale synthesis mandate. This budget reflects the minimum resource investment necessary to convene and sustain a genuinely interdisciplinary team over a timeline sufficient to complete data harmonization, model development, disease/evolutionary analyses, and validation, while providing meaningful, well-supported training experiences for the next generation of data-savvy molecular and cellular scientists.' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   proposals_df.at[idx, col] = progress_lookup.at[uid, col]
# /Users/eveyhuang/Documents/NICO/human-AI-proposal/src/proposal_generation.py:795: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'one_at_a_time::claude-sonnet-5::proposal_call_001' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   proposals_df.at[idx, col] = progress_lookup.at[uid, col]
# /Users/eveyhuang/Documents/NICO/human-AI-proposal/src/proposal_generation.py:795: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'generate_proposals_minimal' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   proposals_df.at[idx, col] = progress_lookup.at[uid, col]
# /Users/eveyhuang/Documents/NICO/human-AI-proposal/src/proposal_generation.py:795: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'v2' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   proposals_df.at[idx, col] = progress_lookup.at[uid, col]
# /Users/eveyhuang/Documents/NICO/human-AI-proposal/src/proposal_generation.py:795: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'claude-sonnet-5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   proposals_df.at[idx, col] = progress_lookup.at[uid, col]
# /Users/eveyhuang/Documents/NICO/human-AI-proposal/src/proposal_generation.py:795: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2026-07-09T11:25:20.104123' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   proposals_df.at[idx, col] = progress_lookup.at[uid, col]
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# INFO:root:AFC is enabled with max remote calls: 10.
# INFO:root:AFC remote call 1 is done.
# /Users/eveyhuang/Documents/NICO/human-AI-proposal/src/proposal_generation.py:795: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Cytokinesis in land plants is executed not by an actomyosin contractile ring but by the phragmoplast, a bipolar microtubule-based scaffold that guides Golgi- and TGN-derived vesicles to a defined equatorial plane, where they fuse to construct a new cell wall in the form of a cell plate. This process is exquisitely sensitive to membrane trafficking fidelity: kinesin motors direct vesicle transport along phragmoplast microtubules, SNARE complexes and exocyst subunits mediate vesicle tethering and fusion, and unconventional/autophagy-related trafficking routes contribute additional membrane material during cell plate maturation and expansion. Disruption at any of these mesoscale nodes—structures intermediate in scale between single biomolecules and whole organelles—can stall or misdirect cytokinesis, with cascading consequences for tissue patterning, organ growth, and, ultimately, agricultural yield. Heat stress is a well-established disruptor of this system, destabilizing microtubule arrays, delaying phragmoplast expansion, and impairing cell plate formation, but nearly all such studies have treated thermal sensitivity as a static, temperature-dependent property. A large and independent body of work on circadian regulation demonstrates that many abiotic stress responses—including transcriptional heat-shock responses—are gated by the time of day, such that identical thermal insults produce markedly different molecular outcomes depending on when they occur relative to the internal clock. This gating phenomenon has never been examined for the endomembrane trafficking machinery that physically builds the cell plate, leaving a fundamental gap: does the circadian clock modulate whether cytokinesis succeeds or fails under heat stress by gating the expression of trafficking regulators themselves? Addressing this question requires reconciling three literatures that have developed largely in isolation—phragmoplast/cell plate cell biology, circadian and thermal stress physiology, and endomembrane trafficking—and doing so across multiple species to distinguish conserved regulatory logic from lineage-specific adaptation. No single dataset captures all the necessary dimensions (time-of-day, temperature, species, and trafficking gene annotation), and no single laboratory possesses the full complement of expertise or infrastructure to integrate them. However, the public data landscape has matured to the point where this integration is feasible: large RNA-seq compendia with time-course and stress designs exist for Arabidopsis, maize, sorghum, and wheat; chromosome-scale, haplotype-resolved genome assemblies now exist for perennial crops such as apple, pear, and peach; and organelle proteomics and live-cell imaging repositories provide independent, orthogonal evidence for trafficking protein localization and dynamics. Synthesizing these resources offers a tractable route to identifying conserved 'bottleneck' genes governing the intersection of circadian timing, thermal stress, and cell-plate trafficking—an emergent mesoscale property with direct relevance to crop resilience under a warming climate, and a question that is significant precisely because it sits at the unexplored interface of three mature but historically disconnected fields.' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   proposals_df.at[idx, col] = progress_lookup.at[uid, col]
# /Users/eveyhuang/Documents/NICO/human-AI-proposal/src/proposal_generation.py:795: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'This project addresses three interlocking questions. First, is the transcriptional sensitivity of cytokinesis-associated trafficking genes to heat stress gated by time of day, analogous to previously documented circadian gating of other stress regulons? We hypothesize that a discrete subset of trafficking genes—particularly those encoding phragmoplast-associated kinesins, cell-plate SNAREs, exocyst components, and autophagy-linked membrane remodeling factors—will show heat-responsiveness that is strongly time-of-day dependent rather than uniform across the diel cycle, mirroring gating patterns previously reported for canonical heat-shock regulons. Second, do these gated trafficking nodes form a conserved regulatory module across phylogenetically distant crop species, or are they lineage-specific outcomes of independent adaptation to distinct thermal regimes? We hypothesize that a core set of trafficking bottleneck genes will be conserved across both annual, short-cycle field crops (Arabidopsis, maize, sorghum, wheat) and perennial, chronically stressed orchard species (apple, pear, peach), reflecting deep conservation of cell-plate biogenesis machinery, while a secondary, lineage-specific layer of gating will reflect differences in life history, exposure duration, and thermal ecology between annual and perennial growth habits. Third, do network-predicted bottleneck genes correspond to independently observed organelle-scale phenotypes—specifically, delayed or aberrant phragmoplast/cell plate maturation—captured in existing live-cell imaging and organelle proteomics datasets? We hypothesize that genes occupying central, highly connected positions in context-specific co-expression modules enriched for trafficking and cytokinesis annotations will disproportionately correspond to proteins already documented, through imaging or proteomic evidence, as spatially or temporally associated with cell plate maturation stages, providing convergent, multi-modal support for their functional importance. Collectively, these hypotheses reframe thermal sensitivity of cytokinesis not as a fixed biochemical property but as an emergent outcome of the interaction between circadian regulatory architecture and trafficking network topology—a property that can only be detected by integrating time-resolved transcriptomic data, cross-species genomic annotation, and orthogonal organelle-scale evidence at a scale no single laboratory's dataset can support. A critical secondary question concerns methodology: can existing network inference approaches, when adapted to explicitly model diel and thermal covariates, reliably distinguish genuine circadian-heat interaction signals from confounding batch, developmental, or tissue-specific variation across heterogeneous public datasets originating from dozens of independent laboratories? We hypothesize that context-specific network construction, incorporating explicit covariate modeling, will substantially reduce spurious co-expression relationships relative to naive aggregation, yielding higher-confidence candidate gene lists suitable for downstream cross-species and cross-modality validation. Together these questions and hypotheses define a tractable, falsifiable synthesis project whose resolution requires exactly the kind of multi-species, multi-omic, cross-disciplinary integration that individual investigators, working within a single species or data type, cannot achieve.' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   proposals_df.at[idx, col] = progress_lookup.at[uid, col]
# /Users/eveyhuang/Documents/NICO/human-AI-proposal/src/proposal_generation.py:795: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'The project proceeds in four integrated phases. Phase 1 (Data Curation): We will systematically identify and catalog publicly available RNA-seq datasets from NCBI SRA/GEO and species-specific repositories that include explicit time-of-day and/or temperature-treatment metadata for Arabidopsis, maize, sorghum, wheat, apple, pear, and peach, prioritizing studies with paired control and heat-stress conditions sampled across multiple circadian time points. Metadata harmonization will standardize treatment, genotype, tissue, and sampling-time annotations into a unified schema. Phase 2 (Reprocessing and Harmonization): All selected raw sequence data will be reprocessed through a standardized, containerized GEMmaker/Nextflow pipeline to generate reproducible, comparably normalized gene expression matrices for each species, eliminating batch effects introduced by heterogeneous original processing pipelines. Existing chromosome-scale, haplotype-resolved genome assemblies and annotation sets for the perennial crops will anchor expression quantification, while established orthology resources will be used to map trafficking, cytokinesis, and circadian clock gene orthologs across all seven species. Phase 3 (Network Construction and Bottleneck Identification): Using the Knowledge Independent Network Construction framework, we will build context-specific gene co-expression networks (csGCNs) for each species that explicitly incorporate time-of-day and temperature as covariates, statistically testing and removing edges attributable to confounding technical or developmental variables. Within each network, modules will be tested for enrichment of curated gene sets representing phragmoplast microtubule motors, cell-plate SNAREs, exocyst subunits, autophagy-related membrane remodeling factors, circadian clock output genes, and canonical heat-shock regulon members. Candidate bottleneck nodes—genes exhibiting both strong circadian-gated expression and heat-responsiveness within trafficking-enriched modules—will be ranked by network centrality and cross-species conservation of orthologous module membership. Phase 4 (Cross-Modal Validation): Candidate genes will be cross-referenced against publicly deposited organelle proteomics datasets and live-cell imaging repositories documenting phragmoplast and cell-plate marker localization, testing whether network-predicted bottlenecks correspond to proteins with documented spatial or temporal association with cell-plate maturation. Comparative statistical analyses (e.g., module preservation statistics, orthogroup enrichment tests) will formally assess conservation versus divergence between annual and perennial lineages. Throughout, all code, containers, and intermediate data products will be version-controlled and benchmarked against held-out datasets to assess pipeline robustness. This approach requires no new experimental data generation; it depends entirely on the reprocessing, harmonization, and multi-modal integration of existing public resources, executed through workflows whose scale and cross-species scope exceed the capacity of any single contributing laboratory.' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   proposals_df.at[idx, col] = progress_lookup.at[uid, col]
# /Users/eveyhuang/Documents/NICO/human-AI-proposal/src/proposal_generation.py:795: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'This synthesis will deliver a ranked, cross-species catalog of candidate trafficking bottleneck genes linking circadian timing to heat-sensitive cytokinesis, accompanied by harmonized expression matrices and context-specific co-expression networks spanning seven crop species. Scientifically, the project will establish whether circadian gating of thermal stress responses extends to the mesoscale trafficking machinery governing cell division, resolving a previously unexamined intersection between two mature but disconnected research areas and reframing cytokinetic thermal sensitivity as an emergent, time-dependent property rather than a fixed biochemical threshold. Agriculturally, identification of conserved versus lineage-specific bottleneck nodes will inform breeding and management strategies aimed at mitigating heat-induced yield loss in both annual field crops and long-lived perennial orchard systems, an increasingly urgent concern under climate change. Methodologically, the project will produce a validated, reusable framework for detecting circadian-environment interaction signals in heterogeneous public transcriptomic data, generalizable to other stress-response systems beyond cytokinesis. The resulting network models and validated gene lists will directly inform testable hypotheses for future hypothesis-driven experiments, effectively de-risking future mechanistic work by prioritizing candidates with convergent transcriptomic, orthological, and organelle-imaging support. Broader impacts include establishing a template for integrating gene regulatory network synthesis with organelle-scale phenotypic data, applicable across NCEMS's mesoscale research priorities. The project will also generate durable community resources—harmonized expression compendia and annotated network models—that lower the barrier for future researchers studying circadian-stress interactions in crop species lacking dedicated experimental infrastructure, thereby expanding participation from researchers at institutions without access to large-scale sequencing or growth chamber facilities.' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   proposals_df.at[idx, col] = progress_lookup.at[uid, col]
# /Users/eveyhuang/Documents/NICO/human-AI-proposal/src/proposal_generation.py:795: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'All aspects of this project will adhere to open science principles consistent with NCEMS policy. Raw data sources will be exclusively drawn from public repositories (SRA, GEO, and species-specific genome databases), with full provenance tracking from original accession to final processed output. All reprocessing will be executed through containerized, version-controlled Nextflow workflows (building on established GEMmaker infrastructure), ensuring that any researcher can reproduce harmonized expression matrices from raw reads using identical software environments. Network construction code, covariate models, and statistical testing scripts will be deposited in public version-controlled repositories (e.g., GitHub, archived via Zenodo for permanent citation) with comprehensive documentation and example datasets. Harmonized expression matrices, context-specific co-expression networks, and ranked candidate gene lists will be released as versioned, citable data products through appropriate community repositories, accompanied by metadata conforming to FAIR data standards. Analysis notebooks documenting the full workflow from data curation through cross-modal validation will be made publicly available to enable independent verification and reuse. The project will maintain a public project website and preregistration of core analytical hypotheses prior to full-scale network analysis, distinguishing confirmatory from exploratory findings. Regular team meetings will document decision points and analytical choices in shared, publicly accessible logs. All resulting manuscripts will be deposited as preprints prior to journal submission, and final publications will pursue open-access routes wherever possible. This comprehensive commitment to transparent, reproducible workflows ensures that the synthesized resources remain usable and extensible by the broader community long after project completion, fulfilling the collaborative, team-science mandate central to NCEMS-supported research.' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   proposals_df.at[idx, col] = progress_lookup.at[uid, col]
# /Users/eveyhuang/Documents/NICO/human-AI-proposal/src/proposal_generation.py:795: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'This project requires resources appropriate to a data synthesis effort rather than new experimental data generation. Primary budget needs include: (1) Personnel—support for a postdoctoral researcher with computational genomics expertise to lead pipeline development and network construction, and graduate student trainees at partner institutions contributing to species-specific data curation, orthology mapping, and cross-modal validation, distributed across the collaborating labs to ensure integrated training; (2) Computational infrastructure—cloud or institutional high-performance computing allocation sufficient to reprocess large-scale RNA-seq compendia across seven species through containerized Nextflow workflows, plus storage for harmonized expression matrices and network models; (3) Software and workflow development—support for extending existing Knowledge Independent Network Construction and GEMmaker infrastructure to accommodate explicit circadian and thermal covariate modeling across multiple species; (4) Travel and coordination—funding for in-person working group meetings to integrate cross-disciplinary expertise in phragmoplast biology, circadian physiology, endomembrane trafficking, and network science, alongside virtual coordination tools for ongoing collaboration among geographically distributed team members; (5) Publication and data deposition costs—open-access publication fees and repository deposition costs to ensure all data products remain freely available. This project explicitly requires NCEMS support because it demands sustained computational infrastructure, cross-institutional personnel coordination, and integration of expertise distributed across five independent laboratories—resources and coordination mechanisms that exceed what any single grant-funded lab could assemble. NCEMS's existing data science and computational support infrastructure will be leveraged for pipeline scaling and network analysis, while the collaborating institutions will contribute existing genome assemblies, annotation pipelines, and domain expertise already developed through prior independently funded work, ensuring efficient use of requested resources and avoiding duplication of existing capabilities.' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   proposals_df.at[idx, col] = progress_lookup.at[uid, col]
# /Users/eveyhuang/Documents/NICO/human-AI-proposal/src/proposal_generation.py:795: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'persona::claude-sonnet-5::proposal_call_001' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   proposals_df.at[idx, col] = progress_lookup.at[uid, col]
# /Users/eveyhuang/Documents/NICO/human-AI-proposal/src/proposal_generation.py:795: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'generate_proposals_persona_minimal' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   proposals_df.at[idx, col] = progress_lookup.at[uid, col]
# /Users/eveyhuang/Documents/NICO/human-AI-proposal/src/proposal_generation.py:795: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'v1' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   proposals_df.at[idx, col] = progress_lookup.at[uid, col]
# /Users/eveyhuang/Documents/NICO/human-AI-proposal/src/proposal_generation.py:795: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'claude-sonnet-5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   proposals_df.at[idx, col] = progress_lookup.at[uid, col]
# /Users/eveyhuang/Documents/NICO/human-AI-proposal/src/proposal_generation.py:795: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2026-07-09T12:54:16.845177' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   proposals_df.at[idx, col] = progress_lookup.at[uid, col]
# Progress file: /Users/eveyhuang/Documents/NICO/human-AI-proposal/data/ai-proposals/one_at_a_time/ai_proposals_one_at_a_time_progress_20260709_095141.csv
# Complete file: /Users/eveyhuang/Documents/NICO/human-AI-proposal/data/ai-proposals/one_at_a_time/ai_proposals_one_at_a_time_complete_20260709_095141.csv
# Rows: 69
#
# === Pass B: persona ===
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# INFO:root:AFC is enabled with max remote calls: 10.
# INFO:root:AFC remote call 1 is done.
# Progress file: /Users/eveyhuang/Documents/NICO/human-AI-proposal/data/ai-proposals/persona/ai_proposals_persona_progress_20260709_095141.csv
# Complete file: None
# Rows: 69
# Proposal QA issues:
#   - missing background_and_significance
#   - missing research_questions_and_hypotheses
#   - missing methods_and_approach
#   - missing expected_outcomes_and_impact
#   - missing open_science_and_reproducibility
#   - missing budget_and_resources
#   - missing background_and_significance
#   - missing research_questions_and_hypotheses
#   - missing methods_and_approach
#   - missing expected_outcomes_and_impact

# %%
summary_rows = []
for condition in CONDITIONS_TO_RUN:
    idea_result = idea_stage_outputs[condition]
    proposal_result = proposal_stage_outputs[condition]
    proposal_df = proposal_result['proposals_df']
    completed_rows = 0
    if not proposal_df.empty:
        completed_rows = int(
            proposal_df['background_and_significance'].fillna('').astype(str).str.strip().ne('').sum()
        )
    summary_rows.append(
        {
            'condition': condition,
            'idea_rows': len(idea_result['ideas_df']),
            'proposal_rows': len(proposal_df),
            'completed_proposals': completed_rows,
            'idea_file': str(idea_result['ideas_path']),
            'proposal_complete_file': str(proposal_result['complete_path']) if proposal_result['complete_path'] else '',
            'idea_reused_existing': idea_result['reused_existing'],
            'proposal_reused_existing': proposal_result['reused_existing'],
            'idea_qa_issue_count': len(idea_result['qa_issues']),
            'proposal_qa_issue_count': len(proposal_result['qa_issues']),
        }
    )

summary_df = pd.DataFrame(summary_rows)
summary_df
# Out:
#        condition  idea_rows  proposal_rows  completed_proposals  \
# 0  one_at_a_time         69             69                   69
# 1        persona         69             69                   67
#
#                                            idea_file  \
# 0  /Users/eveyhuang/Documents/NICO/human-AI-propo...
# 1  /Users/eveyhuang/Documents/NICO/human-AI-propo...
#
#                               proposal_complete_file  idea_reused_existing  \
# 0  /Users/eveyhuang/Documents/NICO/human-AI-propo...                  True
# 1                                                                     True
#
#    proposal_reused_existing  idea_qa_issue_count  proposal_qa_issue_count
# 0                     False                    0                        0
# 1                     False                    0                       12
